# %%
import numpy

pieces = {}
# Monomino
pieces["monomino"] = [(0, 0)]
# Domino
pieces["domino"] = [(0, 0), (1, 0)]
# Trominoes
pieces["tromino_I"] = [(0, 0), (1, 0), (2, 0)]
pieces["tromino_L"] = [(0, 0), (0, 1), (1, 0)]
# Tetrominoes
pieces["tetromino_I"] = [(0, 0), (1, 0), (2, 0), (3, 0)]
pieces["tetromino_L"] = [(0, 0), (0, 1), (0, 2), (1, 0)]
pieces["tetromino_T"] = [(1, 0), (0, 1), (1, 1), (2, 1)]
pieces["tetromino_S"] = [(1, 0), (2, 0), (0, 1), (1, 1)]
pieces["tetromino_square"] = [(0, 0), (1, 0), (0, 1), (1, 1)]
# Pentominoes
pieces["pentomino_F"] = [(0, 0), (0, 1), (1, 1), (2, 1), (1, 2)]
pieces["pentomino_I"] = [(0, 0), (1, 0), (2, 0), (3, 0), (4, 0)]
pieces["pentomino_L"] = [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0)]
pieces["pentomino_N"] = [(0, 0), (0, 1), (1, 1), (2, 1), (2, 2)]
pieces["pentomino_P"] = [(0, 0), (1, 0), (0, 1), (1, 1), (0, 2)]
pieces["pentomino_T"] = [(0, 0), (0, 1), (0, 2), (1, 1), (1, 2)]
pieces["pentomino_U"] = [(0, 0), (0, 1), (1, 0), (1, 1), (0, 2)]
pieces["pentomino_V"] = [(0, 0), (0, 1), (0, 2), (1, 0), (2, 0)]
pieces["pentomino_W"] = [(0, 0), (1, 0), (1, 1), (2, 1), (2, 2)]
pieces["pentomino_X"] = [(1, 0), (0, 1), (1, 1), (2, 1), (1, 2)]
pieces["pentomino_Y"] = [(0, 0), (1, 0), (2, 0), (3, 0), (1, 1)]
pieces["pentomino_Z"] = [(0, 0), (1, 0), (1, 1), (2, 1), (3, 1)]

# %%
'''
Grid
0   1   2   ...  13
14  15  16  ...  27
28  29  30  ...  41
..  ..  ..  ...  ..
182 183 184 ...  195
'''
# Out:
# '\nGrid\n0   1   2   ...  13\n14  15  16  ...  27\n28  29  30  ...  41\n..  ..  ..  ...  ..\n182 183 184 ...  195\n'

# %%
# pieces a dictionary from piece name to
#list of coords
# # List of coords is canonical rep of piece,
# 0 is always the anchor.
# If you shift by any negative of a coord in
# coords list, it gives you all the ways to
# place piece on 0
# Thus, to place on some arbirary grid spot,
# shift coords by that grid spot value,
# and consider all values minus orig vals
# Grid
# 0   1   2   ...  13
# 14  15  16  ...  27
# 28  29  30  ...  41
# ..  ..  ..  ...  ..
# 182 183 184 ...  195
pieces = {}
pieces["monomino"] = (0)
pieces["domino1"] = (0, 1)
pieces["domino2"] = (0, 14)
pieces["tromino_I1"] = (0, 1, 2)
pieces["tromino_I2"] = (0, 14, 28)
pieces["tromino_L1"] = (0, 1, 14)
pieces["tromino_L2"] = (0, 1, 15)
pieces["tromino_L3"] = (0, 14, 15)
pieces["tromino_L4"] = (1, 14, 15)
pieces["tetromino_I1"] = (0, 1, 2, 3)
pieces["tetromino_I2"] = (0, 14, 28, 42)
pieces["tetromino_L1"] = (0, 1, 2, 14)
pieces["tetromino_L2"] = (0, 1, 15, 29)
pieces["tetromino_L3"] = (2, 14, 15, 16)
pieces["tetromino_L4"] = (0, 14, 28, 29)
pieces["tetromino_L5"] = (0, 1, 2, 16)
pieces["tetromino_L6"] = (1, 15, 28, 29)
pieces["tetromino_L7"] = (0, 14, 15, 16)
pieces["tetromino_L8"] = (0, 1, 14, 28)
pieces["tetromino_T1"] = (0, 1, 2, 15)
pieces["tetromino_T2"] = (1, 14, 15, 29)
pieces["tetromino_T3"] = (0, 14, 15, 16)
pieces["tetromino_T4"] = (0, 14, 15, 28)
pieces["tetromino_S1"] = (1, 2, 14, 15)
pieces["tetromino_S2"] = (0, 14, 15, 29)
pieces["tetromino_S3"] = (1, 14, 15, 28)
pieces["tetromino_S4"] = (0, 1, 15, 16)
pieces["tetromino_square"] = (0, 1, 14, 15)
# Grid
# 0   1   2   ...  13
# 14  15  16  ...  27
# 28  29  30  ...  41
# ..  ..  ..  ...  ..
# 182 183 184 ...  195
pieces["pentomino_F1"] = (0, 14, 15, 16, 29)
pieces["pentomino_F2"] = (1, 15, 16, 28, 29)
pieces["pentomino_F3"] = (1, 14, 15, 16, 30)
pieces["pentomino_F4"] = (1, 2, 14, 15, 29)
pieces["pentomino_F5"] = (2, 14, 15, 16, 29)
pieces["pentomino_F6"] = (1, 14, 15, 29, 30)
pieces["pentomino_F7"] = (1, 14, 15, 16, 28)
pieces["pentomino_F8"] = (0, 1, 15, 16, 29)

pieces["pentomino_I1"] = (0, 1, 2, 3, 4)
pieces["pentomino_I2"] = (0, 14, 28, 42, 56)

pieces["pentomino_L1"] = (0, 1, 2, 3, 14)
pieces["pentomino_L2"] = (0, 1, 15, 29, 43)
pieces["pentomino_L3"] = (3, 14, 15, 16, 17)
pieces["pentomino_L4"] = (0, 14, 28, 42, 43)
pieces["pentomino_L5"] = (0, 1, 2, 3, 17)
pieces["pentomino_L6"] = (1, 15, 29, 42, 43)
pieces["pentomino_L7"] = (0, 14, 15, 16, 17)
pieces["pentomino_L8"] = (0, 1, 14, 28, 42)

pieces["pentomino_N1"] = (0, 14, 15, 16, 30)
pieces["pentomino_N2"]  = (2, 14, 15, 16, 28)
pieces["pentomino_N3"] = (1, 2, 15, 28, 29)
pieces["pentomino_N4"] = (0, 1, 15, 29, 30)
# Grid
# 0   1   2   ...  13
# 14  15  16  ...  27
# 28  29  30  ...  41
# ..  ..  ..  ...  ..
# 182 183 184 ...  195
pieces["pentomino_P1"] = (0, 1, 14, 15, 29)
pieces["pentomino_P2"] = (0, 1, 14, 15, 28)
pieces["pentomino_P3"] = (0, 14, 15, 28, 29)
pieces["pentomino_P4"] = (1, 14, 15, 28, 29)
pieces["pentomino_P5"] = (0, 1, 2, 15, 16)
pieces["pentomino_P6"] = (1, 2, 14, 15, 16)
pieces["pentomino_P7"] = (0, 1, 2, 14, 15)
pieces["pentomino_P8"] = (0, 1, 14, 15, 16)

pieces["pentomino_T1"] = (0, 1, 2, 15, 29)
pieces["pentomino_T2"] = (1, 14, 15, 16, 28)
pieces["pentomino_T3"] = (1, 15, 28, 29, 30)
pieces["pentomino_T4"] = (2, 14, 15, 16, 30)

pieces["pentomino_U1"] = (0, 1, 14, 28, 29)
pieces["pentomino_U2"] = (0, 2, 14, 15, 16)
pieces["pentomino_U3"] = (0, 14, 15, 28, 29)
pieces["pentomino_U4"] = (0, 1, 2, 14, 16)

pieces["pentomino_V1"] = (0, 14, 28, 29, 30)
pieces["pentomino_V2"] = (0, 1, 2, 14, 28)
pieces["pentomino_V3"] = (0, 1, 2, 16, 30)
pieces["pentomino_V4"] = (2, 16, 28, 29, 30)

# Grid
# 0   1   2   ...  13
# 14  15  16  ...  27
# 28  29  30  ...  41
# ..  ..  ..  ...  ..
# 182 183 184 ...  195
pieces["pentomino_W1"] = (0, 1, 15, 16, 30)
pieces["pentomino_W2"] = (2, 15, 16, 28, 29)
pieces["pentomino_W3"] = (0, 14, 15, 29, 30)
pieces["pentomino_W4"] = (1, 2, 14, 15, 28)

pieces["pentomino_X1"] = (1, 14, 15, 16, 29)

pieces["pentomino_Y1"] = (0, 1, 2, 3, 15)
pieces["pentomino_Y2"] = (1, 14, 15, 16, 17)
pieces["pentomino_Y3"] = (0, 14, 15, 28, 42)
pieces["pentomino_Y4"] = (1, 14, 15, 29, 43)
pieces["pentomino_Y5"] = (0, 1, 2, 3, 16)
pieces["pentomino_Y6"] = (2, 14, 15, 16, 17)
pieces["pentomino_Y7"] = (0, 14, 28, 29, 42)
pieces["pentomino_Y8"] = (1, 15, 28, 29, 43)

pieces["pentomino_Z1"] = (0, 1, 15, 16, 17)
pieces["pentomino_Z2"] = (2, 3, 14, 15, 16)
pieces["pentomino_Z3"] = (1, 14, 15, 29, 43)
pieces["pentomino_Z4"] = (1, 14, 15, 28, 42)
pieces["pentomino_Z5"] = (1, 2, 3, 14, 15)
pieces["pentomino_Z6"] = (0, 1, 2, 16, 17)
pieces["pentomino_Z7"] = (1, 15, 28, 29, 42)
pieces["pentomino_Z8"] = (0, 14, 28, 29, 43)
